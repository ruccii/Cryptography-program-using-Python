# %% [markdown]
# # Developing a Cryptography program in Python

# %% [markdown]
# ![cryptography%20pic.jpg](attachment:cryptography%20pic.jpg)

# %% [markdown]
# - Program to encrypt a message and then decrypt it when the desired key is entered.

# %%
# !pip install cryptography

# %%
from cryptography.fernet import Fernet

# %%
def generatePasskey():         #generating key
    key = Fernet.generate_key()
    print(key)
    print(type(key))
    file = open("PasswordKey.Key",'wb')
    file.write(key)
    file.close()

# %%
generatePasskey()
# Out:
# b'EuJHtoOxzwpTaDJJuGMpM4y0PUCr5Z6Gl9qaejGalAQ='
# <class 'bytes'>

# %%
def getmykey():
    file = open("PasswordKey.Key",'rb')
    return file.read()

# %%
getmykey()
# Out:
# b'EuJHtoOxzwpTaDJJuGMpM4y0PUCr5Z6Gl9qaejGalAQ='

# %%
def encryptMessage(message_normal):
    key = getmykey()
    k = Fernet(key)
    encrypted_Message = k.encrypt(message_normal)
    return encrypted_Message

# %%
encryptMessage(b"the personal file password for investigation is 1310")
# Out:
# b'gAAAAABgtTRKtdtwQTfLNabYJV-7RVSP0u6ZMtkDUPddaPsP6lDJVl7tgdE8UbQNY-xsM878NVx1gq9_5SZZDPhRo7eESbFpJDV-vtbpwU5UhfCBrGr-_qGgDwbNAKhwyRkXnNR-pJ7lFi3GebQPjZwgc1ORfbBGBw=='

# %%
def decryptMessage(message_secret):
    key = getmykey()
    k = Fernet(key)
    decrypted_Message = k.decrypt(message_secret)
    return decrypted_Message

# %%
decryptMessage(b'gAAAAABgtTRKtdtwQTfLNabYJV-7RVSP0u6ZMtkDUPddaPsP6lDJVl7tgdE8UbQNY-xsM878NVx1gq9_5SZZDPhRo7eESbFpJDV-vtbpwU5UhfCBrGr-_qGgDwbNAKhwyRkXnNR-pJ7lFi3GebQPjZwgc1ORfbBGBw==')
# Out:
# b'the personal file password for investigation is 1310'

# %% [markdown]
# ![lock%20unlock%20gif.gif](attachment:lock%20unlock%20gif.gif)
